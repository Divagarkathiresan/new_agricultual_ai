# %% [markdown]
# <b><h2> CROP YIELD PREDICTION IN INDIA </h2></b>
#
# Predicting yield helps the state to get an estimate of the crop in a
# certain year to control the price rates.This model focuses on predicting the crop yield in advance by analyzing
# factors like location, season, and crop type  through machine learning techniques on
# previously collected datasets.

# %% [markdown]
# # **PRE-PROCESSING**

# %%
# importing necessary libraries 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# loading the dataset
crop_data = pd.read_csv('../datasets/Crop Prediction dataset.csv')
crop_data
# Out:
#          State_Name   District_Name  Crop_Year       Season  \
# 0        Tamil Nadu       Thanjavur       2000  Kharif
# 1        Tamil Nadu       Thanjavur       2000  Kharif
# 2        Tamil Nadu       Thanjavur       2000  Kharif
# 3        Tamil Nadu       Thanjavur       2000  Whole Year
# 4        Tamil Nadu       Thanjavur       2000  Whole Year
# ...             ...             ...        ...          ...
# 49994  Chhattisgarh  JANJGIR-CHAMPA       2006  Kharif
# 49995  Chhattisgarh  JANJGIR-CHAMPA       2006  Kharif
# 49996  Chhattisgarh  JANJGIR-CHAMPA       2006  Kharif
# 49997  Chhattisgarh  JANJGIR-CHAMPA       2006  Kharif
# 49998  Chhattisgarh  JANJGIR-CHAMPA       2006  Rabi
#
#                       Crop  Temperature  Humidity  Soil_Moisture    Area  \
# 0                 Arecanut           36        35             45  1254.0
# 1      Other Kharif pulses           37        40             46     2.0
# 2                     Rice           36        41             50   102.0
# 3                   Banana           37        42             55   176.0
# 4                Cashewnut           36        40             54   720.0
# ...                    ...          ...       ...            ...     ...
# 49994        Small millets           36        35             45    27.0
# 49995             Soyabean           37        40             46    27.0
# 49996            Sunflower           36        41             50   450.0
# 49997                 Urad           37        42             55  1778.0
# 49998                 Gram           36        40             54   216.0
#
#        Production
# 0          2000.0
# 1             1.0
# 2           321.0
# 3           641.0
# 4           165.0
# ...           ...
# 49994         7.0
# 49995        32.0
# 49996       213.0
# 49997       309.0
# 49998       194.0
#
# [49999 rows x 10 columns]

# %%
crop_data.shape

#rows X columns
# Out:
# (49999, 10)

# %%
# dataset columns
crop_data.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop',
#        'Temperature', 'Humidity', 'Soil_Moisture', 'Area', 'Production'],
#       dtype='str')

# %%
# Statistical summary of data frame.

crop_data.describe()
# Out:
#           Crop_Year   Temperature      Humidity  Soil_Moisture           Area  \
# count  49999.000000  49999.000000  49999.000000   49999.000000   49999.000000
# mean    2005.879138     34.445489     44.776116      53.110502    7363.389469
# std        5.106092      3.498524      6.662406       5.258764   27927.935789
# min     1997.000000     25.000000     35.000000      45.000000       0.200000
# 25%     2002.000000     34.000000     40.000000      50.000000      76.000000
# 50%     2006.000000     36.000000     42.000000      54.000000     436.000000
# 75%     2010.000000     36.000000     50.000000      55.000000    2546.500000
# max     2014.000000     37.000000     55.000000      62.000000  877029.000000
#
#          Production
# count  4.978400e+04
# mean   4.132019e+05
# std    1.232609e+07
# min    0.000000e+00
# 25%    8.700000e+01
# 50%    6.384400e+02
# 75%    5.615000e+03
# max    7.801620e+08

# %%
# Checking missing values of the dataset in each column
crop_data.isnull().sum()
# Out:
# State_Name         0
# District_Name      0
# Crop_Year          0
# Season             0
# Crop               0
# Temperature        0
# Humidity           0
# Soil_Moisture      0
# Area               0
# Production       215
# dtype: int64

# %%
# Replacing missing values with mean of the production coloumn
crop_data['Production'] = crop_data['Production'].fillna(crop_data['Production'].mean())
crop_data
# Out:
#          State_Name   District_Name  Crop_Year       Season  \
# 0        Tamil Nadu       Thanjavur       2000  Kharif
# 1        Tamil Nadu       Thanjavur       2000  Kharif
# 2        Tamil Nadu       Thanjavur       2000  Kharif
# 3        Tamil Nadu       Thanjavur       2000  Whole Year
# 4        Tamil Nadu       Thanjavur       2000  Whole Year
# ...             ...             ...        ...          ...
# 49994  Chhattisgarh  JANJGIR-CHAMPA       2006  Kharif
# 49995  Chhattisgarh  JANJGIR-CHAMPA       2006  Kharif
# 49996  Chhattisgarh  JANJGIR-CHAMPA       2006  Kharif
# 49997  Chhattisgarh  JANJGIR-CHAMPA       2006  Kharif
# 49998  Chhattisgarh  JANJGIR-CHAMPA       2006  Rabi
#
#                       Crop  Temperature  Humidity  Soil_Moisture    Area  \
# 0                 Arecanut           36        35             45  1254.0
# 1      Other Kharif pulses           37        40             46     2.0
# 2                     Rice           36        41             50   102.0
# 3                   Banana           37        42             55   176.0
# 4                Cashewnut           36        40             54   720.0
# ...                    ...          ...       ...            ...     ...
# 49994        Small millets           36        35             45    27.0
# 49995             Soyabean           37        40             46    27.0
# 49996            Sunflower           36        41             50   450.0
# 49997                 Urad           37        42             55  1778.0
# 49998                 Gram           36        40             54   216.0
#
#        Production
# 0          2000.0
# 1             1.0
# 2           321.0
# 3           641.0
# 4           165.0
# ...           ...
# 49994         7.0
# 49995        32.0
# 49996       213.0
# 49997       309.0
# 49998       194.0
#
# [49999 rows x 10 columns]

# %%
#checking
crop_data.isnull().values.any()
# Out:
# np.False_

# %%
# Displaying State Names present in the dataset
print(crop_data.State_Name.unique())
print('Total count of states and Union Territories:', len(crop_data.State_Name.unique()))
# Out:
# <StringArray>
# [       'Tamil Nadu',    'Andhra Pradesh', 'Arunachal Pradesh',
#              'Assam',             'Bihar',        'Chandigarh',
#       'Chhattisgarh']
# Length: 7, dtype: str
# Total count of states and Union Territories: 7

# %%
# Adding a new column Yield which indicates Production per unit Area. 

crop_data['Yield'] = (crop_data['Production'] / crop_data['Area'])
crop_data.head(10)
# Out:
#    State_Name District_Name  Crop_Year       Season                 Crop  \
# 0  Tamil Nadu     Thanjavur       2000  Kharif                  Arecanut
# 1  Tamil Nadu     Thanjavur       2000  Kharif       Other Kharif pulses
# 2  Tamil Nadu     Thanjavur       2000  Kharif                      Rice
# 3  Tamil Nadu     Thanjavur       2000  Whole Year                Banana
# 4  Tamil Nadu     Thanjavur       2000  Whole Year             Cashewnut
# 5  Tamil Nadu     Thanjavur       2000  Whole Year              Coconut
# 6  Tamil Nadu     Thanjavur       2000  Whole Year            Dry ginger
# 7  Tamil Nadu     Thanjavur       2000  Whole Year             Sugarcane
# 8  Tamil Nadu     Thanjavur       2000  Whole Year          Sweet potato
# 9  Tamil Nadu     Thanjavur       2000  Whole Year               Tapioca
#
#    Temperature  Humidity  Soil_Moisture     Area  Production        Yield
# 0           36        35             45   1254.0      2000.0     1.594896
# 1           37        40             46      2.0         1.0     0.500000
# 2           36        41             50    102.0       321.0     3.147059
# 3           37        42             55    176.0       641.0     3.642045
# 4           36        40             54    720.0       165.0     0.229167
# 5           34        45             52  18168.0  65100000.0  3583.223250
# 6           34        55             62     36.0       100.0     2.777778
# 7           35        50             59      1.0         2.0     2.000000
# 8           25        55             55      5.0        15.0     3.000000
# 9           36        35             45     40.0       169.0     4.225000

# %%
# Dropping unnecessary columns

data = crop_data.drop(['State_Name'], axis = 1)

# %%
data.corr(numeric_only=True)
# Out:
#                Crop_Year  Temperature  Humidity  Soil_Moisture      Area  \
# Crop_Year       1.000000     0.000505 -0.001339      -0.001533  0.000842
# Temperature     0.000505     1.000000 -0.696194      -0.286471 -0.000204
# Humidity       -0.001339    -0.696194  1.000000       0.812524 -0.000787
# Soil_Moisture  -0.001533    -0.286471  0.812524       1.000000  0.000700
# Area            0.000842    -0.000204 -0.000787       0.000700  1.000000
# Production      0.007962     0.005063 -0.002596      -0.000754  0.027836
# Yield           0.015756     0.000367 -0.000893       0.001810 -0.012039
#
#                Production     Yield
# Crop_Year        0.007962  0.015756
# Temperature      0.005063  0.000367
# Humidity        -0.002596 -0.000893
# Soil_Moisture   -0.000754  0.001810
# Area             0.027836 -0.012039
# Production       1.000000  0.027050
# Yield            0.027050  1.000000

# %%
sns.heatmap(data.corr(numeric_only=True), annot=True, fmt='.4f')
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
dummy = pd.get_dummies(data)
dummy
# Out:
#        Crop_Year  Temperature  Humidity  Soil_Moisture    Area  Production  \
# 0           2000           36        35             45  1254.0      2000.0
# 1           2000           37        40             46     2.0         1.0
# 2           2000           36        41             50   102.0       321.0
# 3           2000           37        42             55   176.0       641.0
# 4           2000           36        40             54   720.0       165.0
# ...          ...          ...       ...            ...     ...         ...
# 49994       2006           36        35             45    27.0         7.0
# 49995       2006           37        40             46    27.0        32.0
# 49996       2006           36        41             50   450.0       213.0
# 49997       2006           37        42             55  1778.0       309.0
# 49998       2006           36        40             54   216.0       194.0
#
#           Yield  District_Name_ANANTAPUR  District_Name_ANJAW  \
# 0      1.594896                    False                False
# 1      0.500000                    False                False
# 2      3.147059                    False                False
# 3      3.642045                    False                False
# 4      0.229167                    False                False
# ...         ...                      ...                  ...
# 49994  0.259259                    False                False
# 49995  1.185185                    False                False
# 49996  0.473333                    False                False
# 49997  0.173791                    False                False
# 49998  0.898148                    False                False
#
#        District_Name_ARARIA  ...  Crop_Tapioca  Crop_Tobacco  Crop_Tomato  \
# 0                     False  ...         False         False        False
# 1                     False  ...         False         False        False
# 2                     False  ...         False         False        False
# 3                     False  ...         False         False        False
# 4                     False  ...         False         False        False
# ...                     ...  ...           ...           ...          ...
# 49994                 False  ...         False         False        False
# 49995                 False  ...         False         False        False
# 49996                 False  ...         False         False        False
# 49997                 False  ...         False         False        False
# 49998                 False  ...         False         False        False
#
#        Crop_Turmeric  Crop_Urad  Crop_Varagu  Crop_Wheat  Crop_other fibres  \
# 0              False      False        False       False              False
# 1              False      False        False       False              False
# 2              False      False        False       False              False
# 3              False      False        False       False              False
# 4              False      False        False       False              False
# ...              ...        ...          ...         ...                ...
# 49994          False      False        False       False              False
# 49995          False      False        False       False              False
# 49996          False      False        False       False              False
# 49997          False       True        False       False              False
# 49998          False      False        False       False              False
#
#        Crop_other misc. pulses  Crop_other oilseeds
# 0                        False                False
# 1                        False                False
# 2                        False                False
# 3                        False                False
# 4                        False                False
# ...                        ...                  ...
# 49994                    False                False
# 49995                    False                False
# 49996                    False                False
# 49997                    False                False
# 49998                    False                False
#
# [49999 rows x 205 columns]

# %% [markdown]
# <b><i> Splitting dataset into train and test dataset </i></b>

# %%
from sklearn.model_selection import train_test_split

x = dummy.drop(["Production","Yield"], axis=1)
y = dummy["Production"]

# Splitting data set - 25% test dataset and 75% 

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=42)

print("x_train :",x_train.shape)
print("x_test :",x_test.shape)
print("y_train :",y_train.shape)
print("y_test :",y_test.shape)
# Out:
# x_train : (37499, 203)
# x_test : (12500, 203)
# y_train : (37499,)
# y_test : (12500,)

# %%
print(x_train)
print(y_train)
# Out:
#        Crop_Year  Temperature  Humidity  Soil_Moisture     Area  \
# 27434       2009           36        40             54   2761.0
# 13400       1999           36        35             45  57620.0
# 883         2013           37        40             46    935.0
# 7303        2004           36        40             54   9065.0
# 49251       2005           36        35             45   7505.0
# ...          ...          ...       ...            ...      ...
# 11284       2002           35        50             59    130.0
# 44732       2013           25        55             55     29.0
# 38158       2010           37        42             55   2347.0
# 860         2013           34        45             52      2.0
# 15795       2009           37        40             46    767.0
#
#        District_Name_ANANTAPUR  District_Name_ANJAW  District_Name_ARARIA  \
# 27434                    False                False                  True
# 13400                    False                False                 False
# 883                       True                False                 False
# 7303                     False                False                 False
# 49251                    False                False                 False
# ...                        ...                  ...                   ...
# 11284                    False                False                 False
# 44732                    False                False                 False
# 38158                    False                False                 False
# 860                       True                False                 False
# 15795                    False                False                 False
#
#        District_Name_ARWAL  District_Name_AURANGABAD  ...  Crop_Tapioca  \
# 27434                False                     False  ...         False
# 13400                False                     False  ...         False
# 883                  False                     False  ...         False
# 7303                 False                     False  ...         False
# 49251                False                     False  ...         False
# ...                    ...                       ...  ...           ...
# 11284                False                     False  ...         False
# 44732                False                     False  ...         False
# 38158                False                     False  ...         False
# 860                  False                     False  ...         False
# 15795                False                     False  ...         False
#
#        Crop_Tobacco  Crop_Tomato  Crop_Turmeric  Crop_Urad  Crop_Varagu  \
# 27434         False        False          False      False        False
# 13400         False        False          False      False        False
# 883           False        False          False      False        False
# 7303          False        False          False      False        False
# 49251         False        False          False      False        False
# ...             ...          ...            ...        ...          ...
# 11284         False        False          False      False        False
# 44732         False        False          False      False        False
# 38158         False        False          False      False        False
# 860           False        False          False      False        False
# 15795         False        False          False       True        False
#
#        Crop_Wheat  Crop_other fibres  Crop_other misc. pulses  \
# 27434       False              False                    False
# 13400       False              False                    False
# 883         False              False                    False
# 7303        False              False                    False
# 49251       False              False                    False
# ...           ...                ...                      ...
# 11284       False              False                    False
# 44732       False              False                    False
# 38158       False              False                    False
# 860         False              False                    False
# 15795       False              False                    False
#
#        Crop_other oilseeds
# 27434                False
# 13400                False
# 883                  False
# 7303                 False
# 49251                False
# ...                    ...
# 11284                False
# 44732                False
# 38158                False
# 860                  False
# 15795                False
#
# [37499 rows x 203 columns]
# 27434     12501.0
# 13400     62814.0
# 883         856.0
# 7303     690146.0
# 49251      1283.0
#            ...
# 11284      1890.0
# 44732        25.0
# 38158      9138.0
# 860          38.0
# 15795       434.0
# Name: Production, Length: 37499, dtype: float64

# %%
# creating the dataset
year = [2012,2013,2014]
values = []
data1 = pd.DataFrame(crop_data)
for x in range(3):
  curyearsum=0
  count=0
  for y in range(1000):
    if(data1.iloc[y]["Crop_Year"] == year[x]):
      count+=1;
      curyearsum += data1.iloc[x]["Humidity"]
  values.append(curyearsum/count)
fig = plt.figure(figsize = (7, 5))
 
# creating the bar plot
x = np.array(["2012","2013","2014"])
y = np.array(values)
plt.xlabel("year")
plt.ylabel("mean value of humidity")
plt.title("mean value of humidity of three years")
plt.bar(x,y,color ='maroon', width = 0.4)
plt.show()

# %%
# creating the dataset
year = [2012,2013,2014]
values = []
data1 = pd.DataFrame(crop_data)
for x in range(3):
  curyearsum=0
  count=0
  for y in range(1000):
    if(data1.iloc[y]["Crop_Year"] == year[x]):
      count+=1;
      curyearsum += data1.iloc[x]["Temperature"]
  values.append(curyearsum/count)
fig = plt.figure(figsize = (7, 5))
 
# creating the bar plot
x = np.array(["2012","2013","2014"])
y = np.array(values)
plt.xlabel("year")
plt.ylabel("mean value of Temperature")
plt.title("mean value of Temperature of three years")
plt.bar(x,y,color ='maroon', width = 0.4)
plt.show()

# %% [markdown]
# # **Linear Regression**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
axes[0].scatter(crop_data['Temperature'], crop_data['Production'], color='red')
axes[1].scatter(crop_data['Soil_Moisture'], crop_data['Production'], color='blue')
axes[0].set_title("Temperature vs Production")
axes[1].set_title("Soil_Moisture vs Production")
axes[0].set_ylabel("Production")
axes[0].set_xlabel("Temperture")
axes[1].set_ylabel("Production")
axes[1].set_xlabel("Soil_Moisture")
plt.show()

# %%
# Training the Simple Linear Regression model .

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr_predict = model.predict(x_test)
lr_predict
# Out:
# array([-111597.24419843, 5260838.98091587, -858253.59636793, ...,
#         116331.28780533, -263273.20635309, -116877.89891186],
#       shape=(12500,))

# %%
from sklearn.metrics import mean_squared_error
lr_predict = model.predict(x_test)
scores_regr = mean_squared_error(y_test, lr_predict)
print(scores_regr)
# print(mean_squared_error(y_train, lr_predict))
# Out:
# 138884209782013.81

# %%
# Predicting the test Results 

lr_predict = model.predict(x_test)
lr_predict
# Out:
# array([-111597.24419843, 5260838.98091587, -858253.59636793, ...,
#         116331.28780533, -263273.20635309, -116877.89891186],
#       shape=(12500,))

# %%
model.score(x_test,y_test)
# Out:
# 0.10237952512110149

# %%
from sklearn.metrics import r2_score
r = r2_score(y_test,lr_predict)
print("R2 score : ",r)
# Out:
# R2 score :  0.10237952512110149

# %%
plt.scatter(y_test,lr_predict)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Linear Regression')
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %% [markdown]
# Clearly, the dataset is not good for linear regression.
#
# <b> Assumptions of Linear Regression </b>
# <ol>
#     <li> Linearity.</li>
#     <li> Homoscedasticity </li>
#     <li> Multivariate normality </li>
#     <li> Lack of multicollinearity </li>

# %% [markdown]
# R2 score: This is pronounced as R-squared, and this score refers to the coefficient of determination.
# This tells us how well the unknown samples will be predicted by our model.

# %% [markdown]
# # <b> Decision Tree </b>

# %%
# Training model 
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 5)
regressor.fit(x_train,y_train)

# Predicting results
decisiontree_predict = regressor.predict(x_test)
decisiontree_predict
# Out:
# array([2051.,  129.,   16., ...,  242., 1000.,  560.], shape=(12500,))

# %%
regressor.score(x_test,y_test)
# Out:
# 0.8648928245820422

# %%
plt.scatter(y_test,decisiontree_predict)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Decision Tree ')
# Out:
# Text(0.5, 1.0, 'Decision Tree ')

# %%
# Calculating R2 score :

from sklearn.metrics import r2_score
r2 = r2_score(y_test,decisiontree_predict)
print("R2 score : ",r2)
# Out:
# R2 score :  0.8648928245820422

# %%
# Calculating Adj. R2 score: 

Adjr2_2 = 1 - (1-r2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
print("Adj. R-Squared : {}".format(Adjr2_2))
# Out:
# Adj. R-Squared : 0.8626622815916514

# %%
ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
sns.distplot(decisiontree_predict, hist = False, color = "b", label = "Predicted Values", ax = ax)
plt.title('Decision Tree Regression')
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_22068\697514152.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
# C:\Users\Alex\AppData\Local\Temp\ipykernel_22068\697514152.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(decisiontree_predict, hist = False, color = "b", label = "Predicted Values", ax = ax)
# Text(0.5, 1.0, 'Decision Tree Regression')

# %% [markdown]
# # **Random Forest Algorithm**

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 11)
model.fit(x_train,y_train)
rf_predict = model.predict(x_test)
rf_predict
# Out:
# array([2947.72727273,  139.72727273,   23.18181818, ...,  310.90909091,
#         940.18181818,  664.45454545], shape=(12500,))

# %%
model.score(x_test,y_test)
# Out:
# 0.8720010350712943

# %%
# Calculating R2 score

from sklearn.metrics import r2_score
r1 = r2_score(y_test,rf_predict)
print("R2 score : ",r1)
# Out:
# R2 score :  0.8720010350712943

# %%
# Calculating Adj. R2 score: 

Adjr2_1 = 1 - (1-r1)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
print("Adj. R-Squared : {}".format(Adjr2_1))
# Out:
# Adj. R-Squared : 0.8698878446125657

# %%
ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
sns.distplot(rf_predict, hist = False, color = "b", label = "Predicted Values", ax = ax)
plt.title('Random Forest Regression')
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_22068\551929062.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
# C:\Users\Alex\AppData\Local\Temp\ipykernel_22068\551929062.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(rf_predict, hist = False, color = "b", label = "Predicted Values", ax = ax)
# Text(0.5, 1.0, 'Random Forest Regression')

# %%
plt.scatter(y_test,rf_predict)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Random Forest')
# Out:
# Text(0.5, 1.0, 'Random Forest')

# %% [markdown]
# <b> Comparison between Linear Regression Algorithm and Random Forest Algorithm </b>

# %% [markdown]
# 1. Linear regression algorithm is not at all accurate for this kind of prediction.
# 2. Random Forest Algorithm has higher accuracy ( between 85 % to 90% ), but it is slow.

# %% [markdown]
# # <b> Support Vector Regression </b>

# %%
#Feature Scaling

from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test = sc_x.fit_transform(x_test)

# %%
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import numpy as np
regr = make_pipeline(StandardScaler(), SVR(kernel='rbf'))
regr.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('svr', SVR())])

# %%
svr_predict = regr.predict(x_test)
svr_predict
# Out:
# array([672.63713137, 701.31935866, 581.99252034, ..., 618.46875558,
#        627.43040287, 602.36562132], shape=(12500,))

# %%
print(regr.score(x_test,y_test))
# Out:
# -0.001093144343699004

# %%
from sklearn.metrics import r2_score
r3 = r2_score(y_test,svr_predict)
print(r3)
# Out:
# -0.001093144343699004

# %%
# Calculating Adj. R2 score: 

Adjr2_3 = 1 - (1-r3)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
print("Adj. R-Squared : {}".format(Adjr2_3))
# Out:
# Adj. R-Squared : -0.017620625500316622

# %%
ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
sns.distplot(svr_predict, hist = False, color = "b", label = "Predicted Values", ax = ax)
plt.title('Support Vector Regression')
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_22068\2646629236.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
# C:\Users\Alex\AppData\Local\Temp\ipykernel_22068\2646629236.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(svr_predict, hist = False, color = "b", label = "Predicted Values", ax = ax)
# Text(0.5, 1.0, 'Support Vector Regression')

# %% [markdown]
# # <b> Cross-validation </b>

# %% [markdown]
# Random Forest

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = model, X = x_train, y=y_train, cv = 10)
accuracies
# Out:
# array([0.94980641, 0.98597755, 0.8774722 , 0.96485447, 0.97312017,
#        0.92955336, 0.96794657, 0.84291392, 0.96177068, 0.95511473])

# %%
a1 = (accuracies.mean()*100)
b1 = (accuracies.std()*100)

# %%
# Mean Accuracy and SD of 10 fold results

print("Accuracy : {:.2f}%".format (accuracies.mean()*100))
print("Standard Deviation : {:.2f}%".format(accuracies.std()*100))
# Out:
# Accuracy : 94.09%
# Standard Deviation : 4.34%

# %% [markdown]
# Decision Tree

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = regressor, X = x_train, y=y_train, cv = 10)

# %%
a2 = (accuracies.mean()*100)
b2 = (accuracies.std()*100)

# %%
print("Accuracy : {:.2f}%".format (accuracies.mean()*100))
print("Standard Deviation : {:.2f}%".format(accuracies.std()*100))
# Out:
# Accuracy : 91.44%
# Standard Deviation : 4.99%

# %% [markdown]
# Support Vector Regressor

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = regressor, X = x_train, y=y_train, cv = 10)

# %%
a3 = (accuracies.mean()*100)
b3 = (accuracies.std()*100)

# %%
print("Accuracy : {:.2f}%".format (accuracies.mean()*100))
print("Standard Deviation : {:.2f}%".format(accuracies.std()*100))
# Out:
# Accuracy : 91.44%
# Standard Deviation : 4.99%

# %% [markdown]
# Comparing with Graphs

# %%
# Mean Accuracy
import numpy as np
import matplotlib.pyplot as plt
 
# create a dataset
Algorithms = ['Random Forest', 'Decision-tree', 'Support Vector Regression']
Accuracy = [a1, a2, a3]

x_pos = np.arange(len(Accuracy))

# Create bars with different colors
plt.bar(x_pos, Accuracy, color=['#488AC7','#ff8c00', '#800000'])

# Create names on the x-axis
plt.xticks(x_pos, Algorithms)
plt.ylabel('Accuracy(in %)')
plt.xlabel('Machine Learning Regression Techniques')

# Show graph
plt.show()

# %%
# Standard Deviation
import numpy as np
import matplotlib.pyplot as plt
 
# create a dataset
Algorithms = ['Random Forest', 'Decision-tree', 'Support Vector Regression']
Accuracy = [b1, b2, b3]

x_pos = np.arange(len(Accuracy))

# Create bars with different colors
plt.bar(x_pos, Accuracy, color=['#488AC7','#ff8c00', '#800000'])

# Create names on the x-axis
plt.xticks(x_pos, Algorithms)
plt.ylabel('Standard Deviation(in %)')
plt.xlabel('Machine Learning Regression Techniques')

# Show graph
plt.show()
plt.savefig('SD.png')

# %%
# Adjusted R2 value
import numpy as np
import matplotlib.pyplot as plt
 
# create a dataset
Algorithms = ['Random Forest', 'Decision-tree', 'Support Vector Regression']
Accuracy = [Adjr2_1, Adjr2_2, Adjr2_3]

x_pos = np.arange(len(Accuracy))

# Create bars with different colors
plt.bar(x_pos, Accuracy, color=['#488AC7','#ff8c00', '#800000'])

# Create names on the x-axis
plt.xticks(x_pos, Algorithms)
plt.ylabel('Adjusted R-Squared Score')
plt.xlabel('Machine Learning Regression Techniques')

# Show graph
plt.show()
plt.savefig('SD.png')

# %%
# R2 Score
import numpy as np
import matplotlib.pyplot as plt
 
# create a dataset
Algorithms = ['Random Forest', 'Decision-tree', 'Support Vector Regression']
Accuracy = [r1, r2, r3]

x_pos = np.arange(len(Accuracy))

# Create bars with different colors
plt.bar(x_pos, Accuracy, color=['#488AC7','#ff8c00', '#800000'])

# Create names on the x-axis
plt.xticks(x_pos, Algorithms)
plt.ylabel('R-Squared Score')
plt.xlabel('Machine Learning Regression Techniques')

# Show graph
plt.show()
plt.savefig('SD.png')
